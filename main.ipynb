# %%
# match case statement

todos = []

while True:
    user_action=input("Type add or show or edit or complete or exit: ")
    user_action=user_action.strip()
            
    match user_action:
        case 'add':
            todo=input('enter a todo : ')
            todos.append(todo)
            file = open('todos.txt','w')
            file.writelines(todos)
        case 'show' | 'display': 
            for index,item in enumerate(todos) :
                item=item.title()
                print(index+1,item)
            # print("hello", index,item)
                # or we can put row=f"{index}:) {item}"
                # print(row)
                           
        case 'edit':
            number=int(input('Number of todo to edit : '))
            number=number-1
            new_todo=input("Enter new todo")
            todos[number]=new_todo


        case 'complete' :
            number=int(input('Number of todo to complete : '))
            # number=number-1
            todos.pop(number-1)


        case 'exit':
            break 
   
        case whatever:
            print("hey u entered wrong command")

print("bye")
# Out:
# bye

# %%
todos = []

while True:
    user_action = input("Type add or show or edit or complete or exit: ")
    user_action = user_action.strip()

    match user_action:
        case 'add':
            todo = input('Enter a todo: ') + "\n"
            todos.append(todo)
            with open('todos.txt', 'a') as file:
                file.write(todo)  # Append the new todo to the file
            

        case 'show' | 'display':
            for index, item in enumerate(todos):
                item = item.title()
                print(index + 1, item)

        case 'edit':
            number = int(input('Number of todo to edit: '))
            if 1 <= number <= len(todos):
                new_todo = input("Enter new todo: ")
                todos[number - 1] = new_todo
            else:
                print("Invalid todo number.")

        case 'complete':
            number = int(input('Number of todo to complete: '))
            if 1 <= number <= len(todos):
                todos.pop(number - 1)
            else:
                print("Invalid todo number.")

        case 'exit':
            break

        case _:
            print("Hey, you entered a wrong command.")

print("Bye")
# Out:
# Bye

# %%
# another version is
# match case statement

# todos = []

while True:
    user_action=input("Type add or show or edit or complete or exit: ")
    user_action=user_action.strip()

    match user_action:
        case 'add':
            todo=input('enter a todo : ') + "\n"
            # here we delete the list and open txt file and read it to it another variable
            file=open('todos.txt','r')
            todos=file.readlines()
            file.close()

            # append the the entered todos to read file and the open txt file in another as write
            # then write inti that
            todos.append(todo)


            file_whatever = open('todos.txt','w')
            file_whatever.writelines(todos)
            file_whatever.close()
            
        case 'show' | 'display': 
            for index,item in enumerate(todos) :
                item=item.title()
                print(index+1,item)
            # print("hello", index,item)
                # or we can put row=f"{index}:) {item}"
                # print(row)
                           
        case 'edit':
            number=int(input('Number of todo to edit : '))
            number=number-1
            new_todo=input("Enter new todo")
            todos[number]=new_todo


        case 'complete' :
            number=int(input('Number of todo to complete : '))
            # number=number-1
            todos.pop(number-1)


        case 'exit':
            break 
   
        case whatever:
            print("hey u entered wrong command")

print("bye")
# Out:
# bye

# %%
# another version is
# match case statement
# read text files


# todos = []
# if suppose todos.txt was in another place outside root location of app
# then u hav to add like
# file=open(r"C:\users\as\downloads\todos.txt",'r')

# file.read()
while True:
    user_action=input("Type add or show or edit or complete or exit: ")
    user_action=user_action.strip()

    match user_action:
        case 'add':
            todo=input('enter a todo : ') + "\n"
            # here we delete the list and open txt file and read it to it another variable
            file=open('files/todos.txt','r')
            todos=file.readlines()
            file.close()

            # append the the entered todos to read file and the open txt file in another as write
            # then write inti that
            todos.append(todo)


            file_whatever = open('files/todos.txt','w')
            file_whatever.writelines(todos)
            file_whatever.close()
            
        case 'show' | 'display': 
            file=open('files/todos.txt', 'r')
            todos=file.readlines()
            file.close()
            for index,item in enumerate(todos) :
                item=item.title()
                print(index+1,item)
            # print("hello", index,item)
                # or we can put row=f"{index}:) {item}"
                # print(row)
                           
        case 'edit':
            number=int(input('Number of todo to edit : '))
            number=number-1
            new_todo=input("Enter new todo")
            todos[number]=new_todo


        case 'complete' :
            number=int(input('Number of todo to complete : '))
            # number=number-1
            todos.pop(number-1)


        case 'exit':
            break 
   
        case whatever:
            print("hey u entered wrong command")

print("bye")
# Out:
# 1 Adsss
#
# 2 Eree
#
# 3 Afa
#
# 4 Qwe
#
# 5 Ass
#
# 6 Addf
#
# 7 Qqqqqqq
#
# 8 Wwwww
#
# 9 Rrrrr
#
# 10 Yyyyy
#
# 11 Uuuu
#
# 12 Ttt
#
# 13 Aefesf
#
# 14 Lhrfu
#
# 15 Jaf
#
# 16 Sljdf;Ljfaddfsfssfsflajdfb
#
# 17 Sdfsfd
#
# 18 Sfsdf
#
# 19 Adjand
#
# 20 Uje Dla
#
# 1 Adsss
#
# 2 Eree
#
# 3 Afa
#
# 4 Qwe
#
# 5 Ass
#
# 6 Addf
#
# 7 Qqqqqqq
#
# 8 Wwwww
#
# 9 Rrrrr
#
# 10 Yyyyy
#
# 11 Uuuu
#
# 12 Ttt
#
# 13 Aefesf
#
# 14 Lhrfu
#
# 15 Jaf
#
# 16 Sljdf;Ljfaddfsfssfsflajdfb
#
# 17 Sdfsfd
#
# 18 Sfsdf
#
# 19 Adjand
#
# 20 Uje Dla
#
# bye

# %%
# another version is
# match case statement
# read text files


# todos = []
# if suppose todos.txt was in another place outside root location of app
# then u hav to add like
# file=open(r"C:\users\as\downloads\todos.txt",'r')

# file.read()
# in this mode,we are  making to delete the liine spaces between each todo
while True:
    user_action=input("Type add or show or edit or complete or exit: ")
    user_action=user_action.strip()

    match user_action:
        case 'add':
            todo=input('enter a todo : ') +"\n"
            # here we delete the list and open txt file and read it to it another variable
            file=open('files/todos.txt','r')
            todos=file.readlines()
            file.close()

            # append the the entered todos to read file and the open txt file in another as write
            # then write inti that
            todos.append(todo)


            file_whatever = open('files/todos.txt','w')
            file_whatever.writelines(todos)
            file_whatever.close()
            
        case 'show' | 'display': 
            file=open('files/todos.txt', 'r')
            todos=file.readlines()
            file.close()
            
            new_todos=[]
            for item in todos:
                new_item=item.strip('\n')
                new_todos.append(new_item)
# instead above method to strip can use list comprehension
# which is shown below

            # new_todo=[item.strip('\n') for item in todos]
            
            print(todos)    

            

            for index,item in enumerate(new_todos) :
                item=item.title()
                print(index+1,item)
            # print("hello", index,item)
                # or we can put row=f"{index}:) {item}"
                # print(row)
                           
        case 'edit':
            number=int(input('Number of todo to edit : '))
            number=number-1
            new_todo=input("Enter new todo")
            todos[number]=new_todo


        case 'complete' :
            number=int(input('Number of todo to complete : '))
            # number=number-1
            todos.pop(number-1)


        case 'exit':
            break 
   
        case whatever:
            print("hey u entered wrong command")

print("bye")
# Out:
# hey u entered wrong command
# ['adsss\n', 'eree\n', 'afa\n', 'qwe\n', 'as\n']
# 1 Adsss
# 2 Eree
# 3 Afa
# 4 Qwe
# 5 As
# ['adsss\n', 'eree\n', 'afa\n', 'qwe\n', 'as\n']
# 1 Adsss
# 2 Eree
# 3 Afa
# 4 Qwe
# 5 As
# bye

# %%
# WHILE CONTEXT MANAGER


while True:
    user_action=input("Type add or show or edit or complete or exit: ")
    user_action=user_action.strip()

    match user_action:
        case 'add':
            todo=input('enter a todo : ') +"\n"
            # here we delete the list and open txt file and read it to it another variable
            file=open('files/todos.txt','r')
            todos=file.readlines()
            file.close()

            with open('files/todos.txt','r') as file:
                todos=file.readlines() 
            # this is gud using in place of above three lines

            todos.append(todo)


            # file_whatever = open('files/todos.txt','w')
            # file_whatever.writelines(todos)
            # file_whatever.close()

            with open('files/todos.txt','w') as file_whatever:
                file_whatever.writelines(todos)

            
        case 'show' | 'display': 
            file=open('files/todos.txt', 'r')
            todos=file.readlines()
            file.close()
            # instead of three lines above  can use below two lines

            with open('files/todos.txt', 'r') as file:
                todos=file.readlines()
#             new_todos=[]
#             for item in todos:
#                 new_item=item.strip('\n')
#                 new_todos.append(new_item)
# # instead above method to strip can use list comprehension
# # which is shown below

#             new_todo=[item.strip('\n') for item in todos]
            
            print(todos)    

            

            for index,item in enumerate(todos) :
                item=item.title()
                print(index+1,item)
            # print("hello", index,item)
                # or we can put row=f"{index}:) {item}"
                # print(row)
                           
        case 'edit':
            number=int(input('Number of todo to edit : '))
            number=number-1
            new_todo=input("Enter new todo")
            todos[number]=new_todo


        case 'complete' :
            number=int(input('Number of todo to complete : '))
            # number=number-1
            todos.pop(number-1)


        case 'exit':
            break 
   
        case whatever:
            print("hey u entered wrong command")

print("bye")

# %%
# WHILE CONTEXT MANAGER

# complete and edit in todos.txt context manager


while True:
    user_action=input("Type add or show or edit or complete or exit: ")
    user_action=user_action.strip()

    match user_action:
        case 'add':
            todo=input('enter a todo : ') +"\n"
            

            with open('files/todos.txt','r') as file:
                todos=file.readlines() 
           

            todos.append(todo)

            with open('files/todos.txt','w') as file_whatever:
                file_whatever.writelines(todos)

            
        case 'show' | 'display': 

            with open('files/todos.txt', 'r') as file:
                todos=file.readlines()
            
            print(todos)
            for index,item in enumerate(todos) :
                item=item.strip('\n')
                row=f"{index+1}-{item}"
                print(row)
                           
        case 'edit':
            number=int(input('Number of todo to edit : '))
            number=number-1
        
            with open('files/todos.txt', 'r') as file:
                todos=file.readlines()

            new_todo=input("Enter new todo")
            todos[number]=new_todo + '\n'


            with open('files/todos.txt','w') as file_whatever:
                file_whatever.writelines(todos)


        case 'complete' :
            number=int(input('Number of todo to complete : '))
            number=number-1
            with open('files/todos.txt', 'r') as file:
                todos=file.readlines()

            todo_to_remove=todos[number-1].strip('\n') 

            todos.pop(number-1)


            with open('files/todos.txt','w') as file_whatever:
                file_whatever.writelines(todos)

            message=f"the removed todo {todo_to_remove} from the list"  
            print(message)  

        case 'exit':
            break 
   
        case whatever:
            print("hey u entered wrong command")

print("bye")
# Out:
# ['as\n', 'sf\n', 'sgeg\n', 'ikk\n', 'efwe\n', 'wfwr\n']
# 1-as
# 2-sf
# 3-sgeg
# 4-ikk
# 5-efwe
# 6-wfwr
# bye

# %%
# to check if password is weak or strong usiing list 


password=input("enter new password: ")

result=[]

if len(password) >= 8:
    result.append(True)

else:
    result.append(False)

digit=False

for i in password:
    if i.isdigit():
        digit=True

result.append(digit)

upper=False
for i in password:
    if i.isupper():
        upper=True
result.append(upper)
        

print(result)
print(all(result))

if all(result) == True:
    print("Strong Password")
else:
    print("Weak Password")
    

# b={"height":12,"width":32, "depth":44}

# %%
# to check if password is weak or strong usiing dictionaries


password=input("enter new password: ")

result={}

if len(password) >= 8:
    result["length"]=True

else:
    result["length"]=False

digit=False
for i in password:
    if i.isdigit():
        digit=True

result["digits"]=digit

upper=False
for i in password:
    if i.isupper():
        upper=True
result["upper-case"]=upper
        

print(result)
# print(all(result))
print(result.values())

if all(result.values()):
    print("Strong Password")
else:
    print("Weak Password")
    

# b={"height":12,"width":32, "depth":44}

# %%
# WHILE CONTEXT MANAGER

# complete and edit in todos.txt context manager


while True:
    user_action=input("Type add or show or edit or complete or exit: ")
    user_action=user_action.strip()

    
    if user_action.startswith("add"):
        
            todo=user_action[4:] + "\n"
            with open('files/todos.txt','r') as file:
                todos=file.readlines() 
        

            todos.append(todo)

            with open('files/todos.txt','w') as file_whatever:
                file_whatever.writelines(todos)
 
            
    elif user_action.startswith("show"):

            with open('files/todos.txt', 'r') as file:
                todos=file.readlines()
            
            print(todos)
            for index,item in enumerate(todos) :
                item=item.strip('\n')
                row=f"{index+1}-{item}"
                print(row)
                           
    elif user_action.startswith("edit"):
        try:        
            number=int(user_action[5:])
            print(number)
            number=number-1
        
            with open('files/todos.txt', 'r') as file:
                todos=file.readlines()

            new_todo=input("Enter new todo")
            todos[number]=new_todo + '\n'


            with open('files/todos.txt','w') as file_whatever:
                file_whatever.writelines(todos)
        except ValueError:
             print("ur command not valid")
             user_action=input("Type add or show or edit or complete or exit: ")
             user_action=user_action.strip()



    elif user_action.startswith("complete"):
            number=int(user_action[9:])
            number=number-1
            with open('files/todos.txt', 'r') as file:
                todos=file.readlines()

            todo_to_remove=todos[number-1].strip('\n') 

            todos.pop(number-1)


            with open('files/todos.txt','w') as file_whatever:
                file_whatever.writelines(todos)

            message=f"the removed todo {todo_to_remove} from the list"  
            print(message)  

    elif user_action.startswith("exit"):
            break 
    
    else:
         print("entered wrong command")

print("bye")
# Out:
#   File <tokenize>:11
#     if user_action.startswith("add"):
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# WHILE CONTEXT MANAGER

# complete and edit in todos.txt context manager


while True:
    user_action=input("Type add or show or edit or complete or exit: ")
    user_action=user_action.strip()

    
    if user_action.startswith("add"):
        
            todo=user_action[4:] + "\n"
            with open('files/todos.txt','r') as file:
                todos=file.readlines() 
        

            todos.append(todo)

            with open('files/todos.txt','w') as file_whatever:
                file_whatever.writelines(todos)
 
            
    elif user_action.startswith("show"):

            with open('files/todos.txt', 'r') as file:
                todos=file.readlines()
            
            print(todos)
            for index,item in enumerate(todos) :
                item=item.strip('\n')
                row=f"{index+1}-{item}"
                print(row)
                           
    elif user_action.startswith("edit"):
        try:        
            number=int(user_action[5:])
            print(number)
            number=number-1
        
            with open('files/todos.txt', 'r') as file:
                todos=file.readlines()

            new_todo=input("Enter new todo")
            todos[number]=new_todo + '\n'


            with open('files/todos.txt','w') as file_whatever:
                file_whatever.writelines(todos)
        except ValueError:
             print("your command not valid")
             continue
             


    elif user_action.startswith("complete"):
             try:   
                number=int(user_action[9:])
                number=number-1
                with open('files/todos.txt', 'r') as file:
                    todos=file.readlines()

                todo_to_remove=todos[number-1].strip('\n') 

                todos.pop(number-1)


                with open('files/todos.txt','w') as file_whatever:
                    file_whatever.writelines(todos)

                message=f"the removed todo {todo_to_remove} from the list"  
                print(message)  
             except IndexError:
                  print("there is no item with that number")
                  continue

    elif user_action.startswith("exit"):
            break 
    
    else:
         print("entered wrong command")

print("bye")

# %%
# custom functions
def get_todos():
    with open('files/todos.txt','r') as file_local:
                todos_local=file_local.readlines() 
    return todos


while True:
    user_action=input("Type add or show or edit or complete or exit: ")
    user_action=user_action.strip()

    
    if user_action.startswith("add"):
        
            todo=user_action[4:] + "\n"
            
            todos=get_todos()
            todos.append(todo)

            with open('files/todos.txt','w') as file_whatever:
                file_whatever.writelines(todos)
 
            
    elif user_action.startswith("show"):

            todos=get_todos()
            print(todos)
            for index,item in enumerate(todos) :
                item=item.strip('\n')
                row=f"{index+1}-{item}"
                print(row)
                           
    elif user_action.startswith("edit"):
        try:        
            number=int(user_action[5:])
            print(number)
            number=number-1
            todos=get_todos()
           
            new_todo=input("Enter new todo")
            todos[number]=new_todo + '\n'


            with open('files/todos.txt','w') as file_whatever:
                file_whatever.writelines(todos)
        except ValueError:
             print("your command not valid")
             continue
             


    elif user_action.startswith("complete"):
             try:   
                number=int(user_action[9:])
                todos=get_todos()
                number=number-1
                
                todo_to_remove=todos[number-1].strip('\n') 

                todos.pop(number-1)

                with open('files/todos.txt','w') as file_whatever:
                    file_whatever.writelines(todos)

                message=f"the removed todo {todo_to_remove} from the list"  
                print(message)  
             except IndexError:
                  print("there is no item with that number")
                  continue

    elif user_action.startswith("exit"):
            break 
    
    else:
         print("entered wrong command")

print("bye")
# Out:
# ['imran\n', 'saj\n', 'ksf\n', 'imran\n', ' add a new member\n', 'skjng\n', 'khaebd\n', 'make pizza\n', 'sjrg\n', 'kshfgr\n', 'lsdf\n', 'hsr\n']
# 1-imran
# 2-saj
# 3-ksf
# 4-imran
# 5- add a new member
# 6-skjng
# 7-khaebd
# 8-make pizza
# 9-sjrg
# 10-kshfgr
# 11-lsdf
# 12-hsr
# bye

# %%
def greet():
    message="hello"
    new_message=message.capitalize()
    print("hey")
    return new_message

greeting=greet()
print(greeting)

# %%
# custom functions with arguments and multiple arguments
def get_todos(filepath):
    with open(filepath,'r') as file_local:
                todos_local=file_local.readlines() 
    return todos_local

# below line is using multiple arguments

def write_todos(filepath,todos_arg):
      with open(filepath,'w') as file_whatever:
            file.writelines(todos_arg)


while True:
    user_action=input("Type add or show or edit or complete or exit: ")
    user_action=user_action.strip()

    
    if user_action.startswith("add"):
        
            todo=user_action[4:] + "\n"
            
            todos=get_todos('files/todos.txt')
            todos.append(todo)

# below two lines can be replaced by write_todos("todos.txt",todos) in functio calling same as for same two lines downwards
            with open('files/todos.txt','w') as file_whatever:
                file_whatever.writelines(todos)
 
            
    elif user_action.startswith("show"):

            todos=get_todos("todos.txt")
            print(todos)
            for index,item in enumerate(todos) :
                item=item.strip('\n')
                row=f"{index+1}-{item}"
                print(row)
                           
    elif user_action.startswith("edit"):
        try:        
            number=int(user_action[5:])
            print(number)
            number=number-1
            todos=get_todos("todos.txt")
           
            new_todo=input("Enter new todo")
            todos[number]=new_todo + '\n'


            with open('files/todos.txt','w') as file_whatever:
                file_whatever.writelines(todos)
        except ValueError:
             print("your command not valid")
             continue
             


    elif user_action.startswith("complete"):
             try:   
                number=int(user_action[9:])
                todos=get_todos("todos.txt")
                number=number-1
                
                todo_to_remove=todos[number-1].strip('\n') 

                todos.pop(number-1)

                with open('files/todos.txt','w') as file_whatever:
                    file_whatever.writelines(todos)

                message=f"the removed todo {todo_to_remove} from the list"  
                print(message)  
             except IndexError:
                  print("there is no item with that number")
                  continue

    elif user_action.startswith("exit"):
            break 
    
    else:
         print("entered wrong command")

print("bye")
# Out:
# bye

# %%
# custom functions with arguments and multiple arguments
def get_todos(filepath="todos.txt"):
    with open(filepath,'r') as file_local:
                todos_local=file_local.readlines() 
    return todos_local

def write_todos(todos_arg, filepath="todos.txt"):
      with open(filepath,'w') as file_whatever:
            file_whatever.writelines(todos_arg)


while True:
    user_action=input("Type add or show or edit or complete or exit: ")
    user_action=user_action.strip()

    
    if user_action.startswith("add"):
        
            todo=user_action[4:] + "\n"
            
            todos=get_todos()
            todos.append(todo)

            write_todos(todos)
 
            
    elif user_action.startswith("show"):

            todos=get_todos("todos.txt")
            print(todos)
            for index,item in enumerate(todos) :
                item=item.strip('\n')
                row=f"{index+1}-{item}"
                print(row)
                           
    elif user_action.startswith("edit"):
        try:        
            number=int(user_action[5:])
            print(number)
            number=number-1
            todos=get_todos("todos.txt")
           
            new_todo=input("Enter new todo")
            todos[number]=new_todo + '\n'


            write_todos(todos)
        except ValueError:
             print("your command not valid")
             continue
             


    elif user_action.startswith("complete"):
             try:   
                number=int(user_action[9:])
                todos=get_todos("todos.txt")
                number=number-1
                
                todo_to_remove=todos[number-1].strip('\n') 

                todos.pop(number-1)

                write_todos("todos.txt",todos)

                message=f"the removed todo {todo_to_remove} from the list"  
                print(message)  
             except IndexError:
                  print("there is no item with that number")
                  continue

    elif user_action.startswith("exit"):
            break 
    
    else:
         print("entered wrong command")

print("bye")
# Out:
# bye

# %%
# documenting code


def get_todos(filepath="todos.txt"):

    """Read a text file and return  
    """
    with open(filepath,'r') as file_local:
                todos_local=file_local.readlines() 
    return todos_local

def write_todos(todos_arg, filepath="todos.txt"):
      with open(filepath,'w') as file_whatever:
            file_whatever.writelines(todos_arg)


while True:
    user_action=input("Type add or show or edit or complete or exit: ")
    user_action=user_action.strip()

    
    if user_action.startswith("add"):
        
            todo=user_action[4:] + "\n"
            
            todos=get_todos()
            todos.append(todo)

            write_todos(todos)
 
            
    elif user_action.startswith("show"):

            todos=get_todos("todos.txt")
            print(todos)
            for index,item in enumerate(todos) :
                item=item.strip('\n')
                row=f"{index+1}-{item}"
                print(row)
                           
    elif user_action.startswith("edit"):
        try:        
            number=int(user_action[5:])
            print(number)
            number=number-1
            todos=get_todos("todos.txt")
           
            new_todo=input("Enter new todo")
            todos[number]=new_todo + '\n'


            write_todos(todos)
        except ValueError:
             print("your command not valid")
             continue
             


    elif user_action.startswith("complete"):
             try:   
                number=int(user_action[9:])
                todos=get_todos("todos.txt")
                number=number-1
                
                todo_to_remove=todos[number-1].strip('\n') 

                todos.pop(number-1)

                write_todos("todos.txt",todos)

                message=f"the removed todo {todo_to_remove} from the list"  
                print(message)  
             except IndexError:
                  print("there is no item with that number")
                  continue

    elif user_action.startswith("exit"):
            break 
    
    else:
         print("entered wrong command")

print("bye")               

help(get_todos)
# Out:
# bye
# Help on function get_todos in module __main__:
#
# get_todos(filepath='todos.txt')
#     Read a text file and return

# %%
# organising codes in modules
from function import get_todos, write_todos

# or we can use import function
# then use  function.get_todos()
# and function.write_todos ineverywher get_todos and write_todos

# ....................
# add a date feature  standard module , constants, if anme equal  main 
# import function 
import time

now=time.strftime("%b %d %Y, %H %M %S")
print("it is, " , now)
#  ...................


while True:
    user_action=input("Type add or show or edit or complete or exit: ")
    user_action=user_action.strip()

    
    if user_action.startswith("add"):
        
            todo=user_action[4:] + "\n"
            
            todos=get_todos()
            todos.append(todo)

            write_todos(todos)
 
            
    elif user_action.startswith("show"):

            todos=get_todos("todos.txt")
            print(todos)
            for index,item in enumerate(todos) :
                item=item.strip('\n')
                row=f"{index+1}-{item}"
                print(row)
                           
    elif user_action.startswith("edit"):
        try:        
            number=int(user_action[5:])
            print(number)
            number=number-1
            todos=get_todos("todos.txt")
           
            new_todo=input("Enter new todo")
            todos[number]=new_todo + '\n'


            write_todos(todos)
        except ValueError:
             print("your command not valid")
             continue
             


    elif user_action.startswith("complete"):
             try:   
                number=int(user_action[9:])
                todos=get_todos("todos.txt")
                number=number-1
                
                todo_to_remove=todos[number-1].strip('\n') 

                todos.pop(number-1)

                write_todos("todos.txt",todos)

                message=f"the removed todo {todo_to_remove} from the list"  
                print(message)  
             except IndexError:
                  print("there is no item with that number")
                  continue

    elif user_action.startswith("exit"):
            break 
    
    else:
         print("entered wrong command")

print("bye")
# Out:
# it is,  Oct 30 2023, 15 49 06
# bye
